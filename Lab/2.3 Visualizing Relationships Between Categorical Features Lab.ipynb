# %% [markdown]
# # Lab Instructions
#
# You have been hired by James Cameron to create profiles of two characters for a reboot of the Titanic Movie: one that is most likely to survive the sinking and one that is least likely to survive.  Mr. Cameron wants this reboot to be as historically accurate as possible, so your profile of each character should be backed up with data and visualizations.
#
# Each character profile should include information on their:
# * Age, fare
# * Sex
# * Passenger class
# * Travel companions (including both parents/children and siblings/spouse)
# * Port of departure (indicated by the Embarked feature in the dataset)
#
# For quantitative features like `Age` and `Fare`, you will need to use the `.loc` method we learned in class (or something similar) to place individuals in categories.  How you choose to do this is up to you, but make sure you explain your reasoning.
#
# You should include at least one visualization for each element of the character profile (age, sex, passenger class, etc.) as evidence.
#
# After you have developed your two character profiles, use your Pandas data wrangling skills to identify at least one real passenger in the dataset that fits each profile.  Print out the names of these individuals.  Look them up in [Encyclopeida Titanica](https://www.encyclopedia-titanica.org/) (or a similar resource).
#
# Tell Mr. Cameron at least one thing about the real passengers who fit your two character profiles that you learned from an external resource.  You need one interesting fact about a person who fits the profile of "most likely to survive" and one interesting fact about a person who fits the profile of "least likely to surivive".

# %%
import pandas as pd

df = pd.read_csv('titanic_passengers.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(x='Age', data=df, hue='Survived')

plt.show()

# %%
df.loc[df['Survived'] == 0, 'Survived_cat'] = 'Died'
df.loc[df['Survived'] == 1, 'Survived_cat'] = 'Survived'

sns.boxplot(x='Age', data=df, y='Survived_cat')
plt.show()

# %%
df['Survived'].dtype
# Out:
# dtype('int64')

# %%
sns.histplot(x='Fare', data=df, hue='Survived')

plt.show()

# %%
sns.boxplot(x='Fare', data=df, y='Survived_cat')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")

plt.figure(figsize=(6,4))
sns.barplot(data=df, x="Sex", y="Survived", ci=None)
plt.title("Survival Rate by Sex")
plt.ylabel("Survival Rate")
plt.xlabel("Sex")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1033/1866934115.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Sex", y="Survived", ci=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")

plt.figure(figsize=(6,4))
sns.barplot(data=df, x="Pclass", y="Survived", ci=None)
plt.title("Survival Rate by Passenger Class")
plt.ylabel("Survival Rate")
plt.xlabel("Pclass")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1033/2505555506.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Pclass", y="Survived", ci=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")

plt.figure(figsize=(6,4))
sns.barplot(data=df, x="Embarked", y="Survived", ci=None)
plt.title("Survival Rate by Port of Departure")
plt.ylabel("Survival Rate")
plt.xlabel("Embarked")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1033/3483945057.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Embarked", y="Survived", ci=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df = df.dropna(subset=["Age"])

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="Age", hue="Survived", multiple="stack", bins=30)
plt.title("Age Distribution by Survival")
plt.xlabel("Age")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")
df["Fare"] = pd.to_numeric(df["Fare"], errors="coerce")
df = df.dropna(subset=["Fare"])

plt.figure(figsize=(8,5))
sns.histplot(data=df, x="Fare", hue="Survived", multiple="stack", bins=30)
plt.title("Fare Distribution by Survival")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")

plt.figure(figsize=(7,4))
sns.barplot(data=df, x="SibSp", y="Survived", ci=None)
plt.title("Survival Rate by Siblings/Spouses Aboard")
plt.ylabel("Survival Rate")
plt.xlabel("SibSp")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1033/896484573.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="SibSp", y="Survived", ci=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("titanic_passengers.csv")

plt.figure(figsize=(7,4))
sns.barplot(data=df, x="Parch", y="Survived", ci=None)
plt.title("Survival Rate by Parents/Children Aboard")
plt.ylabel("Survival Rate")
plt.xlabel("Parch")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1033/71012337.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Parch", y="Survived", ci=None)

# %% [markdown]
# Most likely to live features
#
# Sex: Female
#
# Class: 1st Class
#
# Age: Early 20s
#
# Fare: High (above 70)
#
# Family: Traveling with 1 sibling/spouse or 1 parent/child
#
# Embarked: Cherbourg
#
# Parch:3

# %% [markdown]
# Most likely to die features
#
# Sex: Male
#
# Class: 3rd Class
#
# Age: Around 40 years old
#
# Fare: Very low (under 10)
#
# Family: Traveling alone
#
# Embarked: Southampton
#
# Parch:0

# %% [markdown]
# Using Loc method I first searched for a person likely to live

# %%
df.loc[(df["Sex"]=="female") & (df["Pclass"]==1) & (df["Embarked"]=="C")].sample(1)[["Name","Age","Fare","Pclass","Embarked","Survived","Parch"]]
# Out:
#                                                   Name   Age   Fare  Pclass  \
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  17.0  108.9       1
#
#     Embarked  Survived  Parch
# 307        C         1      0

# %% [markdown]
# 30	    0	    0	    56.9292		C
#
# age   SibSp    Parch    Fare       Port
#
# Looking at thee data age is almost close, SibSp and Parch does not match but fare is close and port is really high for survivability.

# %%
df.loc[(df["Sex"]=="male") & (df["Pclass"]==3) & (df["Embarked"]=="S")].sample(1)[["Name","Age","Fare","Pclass","Embarked","Survived","Parch"]]
# Out:
#                                   Name   Age   Fare  Pclass Embarked  \
# 408  Birkeland, Mr. Hans Martin Monsen  21.0  7.775       3        S
#
#      Survived  Parch
# 408         0      0

# %% [markdown]
# Fare and Age is out of range for least possibility of survival but Parch and port meets the conditions.
